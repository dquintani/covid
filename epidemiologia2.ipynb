# %% [markdown]
# <a href="https://colab.research.google.com/github/dquintani/covid/blob/main/epidemiologia2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # CASOS
#
# Casos diarios y acumulados

# %%
casos_diarios = pd.read_csv("https://github.com/mauforonda/covid19-bolivia-udape/raw/master/confirmados_diarios.csv",
                    index_col = 0)
casos_diarios["Bolivia"] = casos_diarios.sum(axis=1)
casos_diarios.to_csv("casos_diarios.csv")
casos_diarios
# Out:
#             Chuquisaca  La Paz  Cochabamba  ...  Beni  Pando  Bolivia
# 2020-03-10           0       0           0  ...     0      0        0
# 2020-03-11           0       0           0  ...     0      0        1
# 2020-03-12           0       0           0  ...     0      0        0
# 2020-03-13           0       0           1  ...     0      0        7
# 2020-03-14           0       0           0  ...     0      0        0
# ...                ...     ...         ...  ...   ...    ...      ...
# 2021-06-19         167     604         272  ...    28      4     1648
# 2021-06-20         139     294         337  ...    19     15     1086
# 2021-06-21         113     213         188  ...    17     13      764
# 2021-06-22         153     124         390  ...    35     17     1667
# 2021-06-23         154     419         469  ...    84     13     2270
#
# [471 rows x 10 columns]

# %%
casos_acumulados = casos_diarios.cumsum(axis = 0)
casos_acumulados.to_csv("casos_acumulados.csv")

casos_acumulados
# Out:
#             Chuquisaca  La Paz  Cochabamba  ...   Beni  Pando  Bolivia
# 2020-03-10           0       0           0  ...      0      0        0
# 2020-03-11           0       0           0  ...      0      0        1
# 2020-03-12           0       0           0  ...      0      0        1
# 2020-03-13           0       0           1  ...      0      0        8
# 2020-03-14           0       0           1  ...      0      0        8
# ...                ...     ...         ...  ...    ...    ...      ...
# 2021-06-19       25193   87683       60959  ...  19306   6491   420960
# 2021-06-20       25332   87977       61296  ...  19325   6506   422046
# 2021-06-21       25445   88190       61484  ...  19342   6519   422810
# 2021-06-22       25598   88314       61874  ...  19377   6536   424477
# 2021-06-23       25752   88733       62343  ...  19461   6549   426747
#
# [471 rows x 10 columns]

# %% [markdown]
# # Muertes
#
# Muertes diarias y acumuladas

# %%
muertes_diarias = pd.read_csv("https://github.com/mauforonda/covid19-bolivia-udape/raw/master/decesos_diarios.csv",
                    index_col = 0)
muertes_diarias["Bolivia"] = muertes_diarias.sum(axis=1)
muertes_diarias.to_csv("muertes_diarias.csv")

muertes_diarias
# Out:
#             Chuquisaca  La Paz  Cochabamba  ...  Beni  Pando  Bolivia
# 2020-03-10           0       0           0  ...     0      0        0
# 2020-03-11           0       0           0  ...     0      0        0
# 2020-03-12           0       0           0  ...     0      0        0
# 2020-03-13           0       0           0  ...     0      0        0
# 2020-03-14           0       0           0  ...     0      0        0
# ...                ...     ...         ...  ...   ...    ...      ...
# 2021-06-19          15       5          17  ...     5      0       79
# 2021-06-20           4       5          19  ...     1      0       44
# 2021-06-21           8       8          11  ...     1      3       42
# 2021-06-22           6       6          20  ...     3      3       69
# 2021-06-23           6       4          24  ...     1      0       86
#
# [471 rows x 10 columns]

# %%
muertes_acumuladas = muertes_diarias.cumsum(axis = 0)
muertes_acumuladas.to_csv("muertes_acumuladas.csv")

muertes_acumuladas
# Out:
#             Chuquisaca  La Paz  Cochabamba  ...  Beni  Pando  Bolivia
# 2020-03-10           0       0           0  ...     0      0        0
# 2020-03-11           0       0           0  ...     0      0        0
# 2020-03-12           0       0           0  ...     0      0        0
# 2020-03-13           0       0           0  ...     0      0        0
# 2020-03-14           0       0           0  ...     0      0        0
# ...                ...     ...         ...  ...   ...    ...      ...
# 2021-06-19        1111    2250        2378  ...   821    301    14461
# 2021-06-20        1115    2255        2397  ...   822    301    14505
# 2021-06-21        1123    2263        2408  ...   823    304    14547
# 2021-06-22        1129    2269        2428  ...   826    307    14616
# 2021-06-23        1135    2273        2452  ...   827    307    14702
#
# [471 rows x 10 columns]

# %% [markdown]
# # Pruebas

# %%
pruebas_edu = pd.read_csv("https://raw.githubusercontent.com/pr0nstar/covid19-data/master/processed/bolivia/testing.csv",
                    index_col = 0)
pruebas_edu = pruebas_edu[pruebas_edu.columns].apply(pd.to_numeric, errors = "coerce")
pruebas_edu
# Out:
#             La Paz  Unnamed: 2  Cochabamba  ...  Unnamed: 16  Pando  Unnamed: 18
# Fecha                                       ...
# NaN            NaN         NaN         NaN  ...          NaN    NaN          NaN
# 2020-05-07    51.0      2294.0        25.0  ...        230.0   15.0         76.0
# 2020-05-08    64.0      2399.0        29.0  ...        230.0   13.0         79.0
# 2020-05-09    67.0      2515.0        29.0  ...        239.0    NaN          NaN
# 2020-05-10    57.0      2578.0        29.0  ...        244.0    NaN          NaN
# ...            ...         ...         ...  ...          ...    ...          ...
# 2021-06-19   743.0    255195.0       400.0  ...      40640.0   15.0      16415.0
# 2021-06-20   700.0    257367.0       370.0  ...      40685.0  101.0      16496.0
# 2021-06-21   552.0    258521.0       280.0  ...      40778.0  117.0      16520.0
# 2021-06-22  2213.0    259497.0       340.0  ...      40943.0   82.0      16600.0
# 2021-06-23  1869.0    262596.0       400.0  ...      41120.0   81.0      16677.0
#
# [414 rows x 18 columns]

# %%
col_names = ['La Paz', 'Cochabamba', 'Santa Cruz','Oruro','Potosí','Tarija','Chuquisaca', 'Beni','Pando']

# %%
descartados = pruebas_edu.iloc[1:,[1,3,5,7,9,11,13,15,17]]
for i in range(9):
    descartados.rename(columns={descartados.columns[i] : col_names[i]}, inplace=True)
descartados["Bolivia"] = descartados.sum(axis=1, min_count=9)

descartados.to_csv("descartados_acumulados.csv")


descartados
# Out:
#               La Paz  Cochabamba  Santa Cruz  ...     Beni    Pando    Bolivia
# Fecha                                         ...
# 2020-05-07    2294.0      1159.0      3444.0  ...    230.0     76.0     8049.0
# 2020-05-08    2399.0      1203.0      3532.0  ...    230.0     79.0     8321.0
# 2020-05-09    2515.0      1244.0      3638.0  ...    239.0      NaN        NaN
# 2020-05-10    2578.0      1252.0      3889.0  ...    244.0      NaN        NaN
# 2020-05-11    2657.0      1256.0      4346.0  ...    253.0     95.0        NaN
# ...              ...         ...         ...  ...      ...      ...        ...
# 2021-06-19  255195.0    240213.0    531298.0  ...  40640.0  16415.0  1301402.0
# 2021-06-20  257367.0    241115.0    532092.0  ...  40685.0  16496.0  1306054.0
# 2021-06-21  258521.0    241870.0    532980.0  ...  40778.0  16520.0  1309431.0
# 2021-06-22  259497.0    244297.0    537241.0  ...  40943.0  16600.0  1318591.0
# 2021-06-23  262596.0    246671.0    541090.0  ...  41120.0  16677.0  1329974.0
#
# [413 rows x 10 columns]

# %%
sospechosos = pruebas_edu.iloc[1:,[0,2,4,6,8,10,12,14,16]]
#for i in range(9):
#    sospechosos.rename(columns={sospechosos.columns[i] : col_names[i]}, inplace=True)
sospechosos["Bolivia"] = sospechosos.sum(axis=1)
#sospechosos

# %%
pruebas_acum = casos_acumulados + descartados
pruebas_acum = pruebas_acum.drop(pruebas_acum.index[0:58], axis=0)
pruebas_acum["La Paz"].plot(figsize = (15,7))

pruebas_acum.to_csv("pruebas_acum.csv")

pruebas_acum[55:75]
# Out:
#               Beni   Bolivia  Chuquisaca  ...  Potosí  Santa Cruz  Tarija
# 2020-07-01  6724.0       NaN         NaN  ...  2722.0     35735.0  2499.0
# 2020-07-02  6803.0   79565.0      3321.0  ...  2757.0     36589.0  2652.0
# 2020-07-03  6929.0   81784.0      3491.0  ...  2805.0     37282.0  2844.0
# 2020-07-04  6943.0   83956.0      3742.0  ...  2858.0     38064.0  3045.0
# 2020-07-05  6943.0   86876.0      3853.0  ...  2874.0     39550.0  3168.0
# 2020-07-06  7026.0   88816.0      3930.0  ...  2932.0     39842.0  3270.0
# 2020-07-07  7233.0       NaN      4140.0  ...  2992.0         NaN  3359.0
# 2020-07-08  7474.0   92826.0      4261.0  ...  3049.0     41049.0  3596.0
# 2020-07-09  7726.0   94857.0      4526.0  ...  3069.0     41534.0  3795.0
# 2020-07-10  7890.0   97053.0      4530.0  ...  3091.0     42298.0  4065.0
# 2020-07-11  7931.0   99753.0      5026.0  ...  3118.0     43020.0  4193.0
# 2020-07-12  7976.0       NaN      5155.0  ...  3197.0     43435.0  4193.0
# 2020-07-13  8021.0  103095.0      5155.0  ...  3268.0     43913.0  4250.0
# 2020-07-14  8085.0  106054.0      5387.0  ...  3345.0     44922.0  4417.0
# 2020-07-15  8216.0       NaN      5606.0  ...  3409.0     45575.0  4623.0
# 2020-07-16  8339.0  111211.0      5922.0  ...  3527.0     46900.0  4845.0
# 2020-07-17  8365.0  114178.0      5907.0  ...  3567.0     48707.0  5096.0
# 2020-07-18  8398.0  117199.0      6039.0  ...  3589.0     49335.0  5576.0
# 2020-07-19  8429.0  119763.0      6123.0  ...  3758.0     49752.0  5748.0
# 2020-07-20  8476.0  121786.0      6185.0  ...  3780.0     50359.0  5883.0
#
# [20 rows x 10 columns]

# %%
pruebas_acum.to_csv("pruebas_acum.csv")

# %%
pruebas_diarias_NaN = pruebas_acum.diff()
pruebas_diarias = pruebas_diarias_NaN[pruebas_diarias_NaN > 0 ]
pruebas_diarias["Potosí"].plot(figsize = (15,7))

pruebas_diarias.to_csv("pruebas_diarias.csv")

pruebas_diarias
# Out:
#              Beni  Bolivia  Chuquisaca  ...  Potosí  Santa Cruz  Tarija
# 2020-05-07    NaN      NaN         NaN  ...     NaN         NaN     NaN
# 2020-05-08   81.0    457.0         1.0  ...    14.0       157.0    13.0
# 2020-05-09    9.0      NaN         NaN  ...    16.0       256.0     2.0
# 2020-05-10    7.0      NaN         NaN  ...    29.0       347.0     NaN
# 2020-05-11   84.0      NaN        11.0  ...     NaN       647.0     1.0
# ...           ...      ...         ...  ...     ...         ...     ...
# 2021-06-19  118.0   9088.0       934.0  ...   227.0      2383.0   231.0
# 2021-06-20   64.0   5738.0       385.0  ...   272.0       915.0    80.0
# 2021-06-21  110.0   4141.0       326.0  ...    95.0      1003.0   114.0
# 2021-06-22  200.0  10827.0       571.0  ...   149.0      4919.0   713.0
# 2021-06-23  261.0  13653.0       675.0  ...   421.0      4587.0   775.0
#
# [413 rows x 10 columns]

# %% [markdown]
# # Positividad

# %%
positividad_diaria = casos_diarios / pruebas_diarias
positividad_diaria = positividad_diaria.drop(positividad_diaria.index[0:59])
positividad_diaria["Potosí"].plot(figsize = (15,7))

positividad_diaria.to_csv("positividad_diaria.csv")

positividad_diaria[360:380]
# Out:
#                 Beni   Bolivia  Chuquisaca  ...    Potosí  Santa Cruz    Tarija
# 2021-05-03  0.131313       NaN    0.250000  ...       NaN    0.105243  0.291498
# 2021-05-04  0.414384  0.153668    0.268657  ...  0.616667    0.103585  0.246377
# 2021-05-05  0.313076  0.162433    0.219207  ...  0.368794    0.120588  0.246212
# 2021-05-06  0.142480  0.185016    0.375000  ...  0.287879    0.163055  0.206963
# 2021-05-07       NaN       NaN    0.348485  ...  0.241611    0.183010  0.245580
# 2021-05-08       NaN       NaN    0.250000  ...  0.231760    0.207921  0.197861
# 2021-05-09       NaN       NaN    0.215164  ...  0.311111    0.192173  0.460000
# 2021-05-10       NaN       NaN    0.339130  ...  0.183824    0.160364  0.269777
# 2021-05-11  0.317757       NaN    0.301047  ...       NaN    0.167324  0.333333
# 2021-05-12  0.266254       NaN    0.360434  ...       NaN    0.187528  0.262118
# 2021-05-13  0.268966  0.198785    0.251948  ...  0.354497    0.155777  0.302658
# 2021-05-14  0.385666  0.234486    0.327078  ...  0.240664    0.182672  0.262595
# 2021-05-15  0.280000  0.256473    0.278481  ...  0.382114    0.259503  0.369128
# 2021-05-16  0.333333  0.241221    0.292593  ...  0.435897    0.238481  0.294872
# 2021-05-17  0.355450  0.237279    0.264808  ...  0.093023    0.228000  0.288984
# 2021-05-18  0.195652  0.235278    0.265010  ...  0.347368    0.223993  0.330409
# 2021-05-19  0.261307  0.223678    0.345114  ...  0.496933    0.181007  0.299572
# 2021-05-20  0.116972  0.219593    0.321330  ...  0.303797    0.219298  0.228275
# 2021-05-21  0.167347       NaN    0.293355  ...  0.274854    0.226386  0.244073
# 2021-05-22  0.291892       NaN    0.272085  ...  0.196133    0.192882  0.307479
#
# [20 rows x 10 columns]

# %%
positividad_diaria_adj = positividad_diaria.rolling(7,min_periods=1).mean()


positividad_diaria_adj.to_csv("positividad_diaria_ajuste.csv")

positividad_diaria_adj[360:380]
# Out:
#                 Beni   Bolivia  Chuquisaca  ...    Potosí  Santa Cruz    Tarija
# 2021-05-03  0.271287  0.136493    0.217097  ...  0.314906    0.102250  0.239888
# 2021-05-04  0.304844  0.146732    0.226420  ...  0.428532    0.099753  0.242281
# 2021-05-05  0.328451  0.158050    0.235788  ...  0.410731    0.100630  0.247647
# 2021-05-06  0.301674  0.167039    0.259719  ...  0.418335    0.111933  0.249603
# 2021-05-07  0.327339  0.167039    0.282216  ...  0.378738    0.122102  0.249645
# 2021-05-08  0.264866  0.167039    0.289452  ...  0.349342    0.141523  0.247784
# 2021-05-09  0.250313  0.167039    0.275216  ...  0.342970    0.153654  0.270642
# 2021-05-10  0.289980  0.167039    0.287949  ...  0.320235    0.161528  0.267539
# 2021-05-11  0.257771  0.173724    0.292576  ...  0.270830    0.170634  0.279961
# 2021-05-12  0.242164  0.185016    0.312751  ...  0.251237    0.180196  0.282233
# 2021-05-13  0.284325  0.198785    0.295173  ...  0.264560    0.179157  0.295904
# 2021-05-14  0.309660  0.216635    0.292114  ...  0.264371    0.179108  0.298335
# 2021-05-15  0.303728  0.229915    0.296183  ...  0.294442    0.186477  0.322801
# 2021-05-16  0.308663  0.232741    0.307244  ...  0.319399    0.193093  0.299212
# 2021-05-17  0.315346  0.233649    0.296627  ...  0.301239    0.202755  0.301956
# 2021-05-18  0.297903  0.233920    0.291479  ...  0.308927    0.210850  0.301538
# 2021-05-19  0.297196  0.232457    0.289290  ...  0.335785    0.209919  0.306888
# 2021-05-20  0.275483  0.235430    0.299202  ...  0.328542    0.218993  0.296262
# 2021-05-21  0.244295  0.235587    0.294384  ...  0.333427    0.225238  0.293616
# 2021-05-22  0.245993  0.231410    0.293471  ...  0.306858    0.215721  0.284809
#
# [20 rows x 10 columns]

# %%
positividad_diaria_adj.plot(figsize = (20,8))

# %%
fig, ax = plt.subplots(figsize=(20,8))
axs = (positividad_diaria_adj).plot(
    subplots=True, layout=(2,5), sharey=True, figsize = (20,8))

at = axs[0][0].get_figure().suptitle('positividad', y=.91)

# %%
fig.savefig("/drive/My Drive/Colab Notebooks/epidemiologia/positividad.jpg")

# %% [markdown]
# hi

# %%
subregistro = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQ7tROls-iID68r9D9bRMlXZxlTpm00oXbYa8kS6VYm4-4F1EaI_-vQVKjYW8zPqCup1TOgq-d3cgA6/pub?gid=1000793550&single=true&output=csv")
subregistro
# Out:
#    Unnamed: 0 La Paz Cochabamba Santa Cruz  ...  Chuquisaca   Beni  Pando  Bolivia
# 0     2020-01    NaN        NaN        NaN  ...         NaN    NaN    NaN      NaN
# 1     2020-02    NaN        NaN        NaN  ...         NaN    NaN    NaN      NaN
# 2     2020-03      0         12        315  ...       -21.0   27.0    6.0      227
# 3     2020-04   -238       -196       -432  ...       -48.0  -98.0  -13.0   -1,258
# 4     2020-05   -172       -160        221  ...       -27.0   82.0   -1.0     -256
# 5     2020-06    230        431      2,133  ...       -69.0  182.0   12.0    2,868
# 6     2020-07  5,754      1,392        620  ...       149.0  233.0   -3.0    9,168
# 7     2020-08  2,742        286       -308  ...       150.0   14.0   -8.0    3,951
# 8     2020-09     42       -195       -386  ...        -3.0  -61.0    0.0     -461
# 9     2020-10     -9       -143       -201  ...        34.0    5.0   -5.0     -233
# 10    2020-11    128         90        265  ...       -21.0   19.0   -9.0      508
# 11    2020-12    198       -121        -60  ...       -43.0  -31.0    5.0     -125
# 12    2021-01  2,669         84        315  ...       -54.0   51.0    9.0    3,338
# 13    2021-02  1,118        133         30  ...       -31.0    9.0  -16.0    1,496
# 14    2021-03    424        142        110  ...        18.0   90.0    7.0      973
# 15    2021-04    151        169         87  ...         3.0   12.0   -5.0      434
# 16    2021-05    521        878        728  ...        19.0   -3.0    2.0    2,431
# 17    2021-06     69         69         69  ...        69.0   69.0   69.0       69
#
# [18 rows x 11 columns]

# %%
subregistro.to_csv("subregistro.csv")

# %%
from google.colab import drive
drive.mount("/drive")
# Out:
# Mounted at /drive

# %%
subregistro.to_csv("/drive/My Drive/Colab Notebooks/epidemiologia/subregistro_google.csv")
